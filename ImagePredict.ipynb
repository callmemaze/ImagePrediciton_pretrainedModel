# %%
#Import modules
import numpy as np
from keras.preprocessing import image
from keras.applications import vgg16
import matplotlib.pyplot as plt
from pathlib import Path

# %%
#Image path 
path = Path("/content/dogs_pic.jpeg")

# %%
#Load the image
img = image.load_img(path, target_size=(224,224))
image_array = image.img_to_array(img)

# %%
#Expanding the dimension
x_train = np.expand_dims(image_array, axis=0)

# %%
#Normalize the data
x_train = resnet.preprocess_input(x_train)

# %%
plt.(path)
plt.imshow(data)
plt.show()

# %%
#Model
model = vgg16.VGG16(weights="imagenet")

# %% [markdown]
# VGG16 is used in this model as VGG16 is a pretrained model but we can use any other pretrained model like ResNet model too. for using ResNet model
#
# from keras.applications import resnet
#
# model = resnet.ResNet50(weights="imagenet")

# %%
#Prediction
prediction = model.predict(x_train)

# %%
pred = vgg16.decode_predictions(prediction)

# %% [markdown]
# if using a resnet model
#
# pred = resnet.decode_predictions(prediction)

# %%
print(pred)
# Out:
# [[('n02099601', 'golden_retriever', 0.9131114), ('n02104029', 'kuvasz', 0.042777713), ('n02099712', 'Labrador_retriever', 0.025398213), ('n02113799', 'standard_poodle', 0.0061599463), ('n02111500', 'Great_Pyrenees', 0.0010418283)]]
